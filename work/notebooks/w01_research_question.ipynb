# %% [markdown]
# <a href="https://colab.research.google.com/github/hydroz3/flyrank-ml-intern/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hydroz3/flyrank-ml-intern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

'''
I will pick Refresh / Content Opportunity Scoring as I want to build a product-related Machine Learning project that improve decision making. In this project, I want to build a ranked action engine that can check which pages should be reviewed first with good code-based reasoning.
'''

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
'''
The work improve the signal outcomes of the search engine through better Machine Learning models (building a ranked action queue). The outcome here is to ensure the pages in the search engine is more clickable by giving better suggestions for editors' pages.

From these suggestions, the editors will observe the context and eplanation of the page performance, including the suggested action such as Refresh, Protect, Expand, Prune, Monitor or etc.

If there's wrong recommendations, such as if the suggestion is prune but the page is doing well (good CTR score), it may lessen potential customers going through the page. On the other hand, if the page is not doing well and the suggestion is expand, it may significantly hurt the CTR for pages that are more uninteresting.
'''

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_974/3400693085.py in <cell line: 0>()
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All
#       3 import pandas as pd
# ----> 4 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       5 df.head()
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
'''
My claims or work has to say more careful words like observe/directional/decision-support claims (such as "this suggests" instead of "this proves").

It will never claim that I prove Google's algorithm, predict google or claim that a refresh caused a recovery, unless if I run a valid causal (related to cause and effect) design.
'''

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
